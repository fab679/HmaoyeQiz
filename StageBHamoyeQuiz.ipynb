# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns

# %%
import io
import requests
url ="https://archive.ics.uci.edu/ml/machine-learning-databases/00374/energydata_complete.csv"
c = requests.get(url).content
energy = pd.read_csv(io.StringIO(c.decode('utf-8')), parse_dates=True)

# %%
X = np.array(energy['T2']).reshape((-1,1))
y =energy['T6']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)
print(y_pred)
# Out:
# [6.75111898 6.03302778 7.58765822 ... 2.2352877  7.58765822 6.67708896]

# %%
print(regressor.coef_)
# Out:
# [2.22090063]

# %%
print(regressor.intercept_)
# Out:
# -37.274534563884444

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.6549368657753506

# %%
from sklearn.metrics import mean_absolute_error
error = mean_absolute_error(X_train,y_train)
error
# Out:
# 12.461405375793879

# %%
from sklearn.metrics import mean_squared_error

mean = mean_absolute_error(X_train,y_train)
mean
# Out:
# 12.461405375793879
